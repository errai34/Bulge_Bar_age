# %% [markdown]
# # Small code to split the original data into training and testing sets

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

np.random.seed(1234)

# %%
data = pd.read_csv('AllOriginal.csv')
print("Length of data before dropping NaN: ", len(data))
data = data.dropna()
print("Length of data after dropping NaN: ", len(data))
# Out:
# Length of data before dropping NaN:  3010
# Length of data after dropping NaN:  3009

# %%
data.head()
# Out:
#             APOGEE_ID            source_id      LOGG         TEFF     MG_FE  \
# 0  2M18401969+4348380  2117126509915136384  2.871106  4723.436035  0.042202
# 1  2M18405556+4353012  2117149874537225344  3.000676  4952.732910  0.027853
# 2  2M18410298+4315506  2116830779945635200  2.901085  5117.872559 -0.050061
# 3  2M18413176+4358551  2116969387130311040  3.180513  4796.577148  0.040342
# 4  2M18420846+4315092  2116909291947572736  3.039876  4725.524902  0.149952
#
#      FE_H_1      C_FE      N_FE          G         BP  ...  age_68L   ageErr  \
# 0  0.049127 -0.016018  0.197207  11.753538  12.318904  ...   6.8391  1.98220
# 1 -0.178222 -0.012749  0.202450  12.680544  13.187252  ...   2.8510  0.82995
# 2 -0.016609 -0.104168  0.372032  11.452943  11.927316  ...   0.4732  0.04970
# 3  0.176768  0.041310  0.296720  12.788189  13.337189  ...   5.6442  1.58165
# 4  0.141578  0.133760  0.215050  11.997146  12.540438  ...   7.7625  2.20010
#
#      logAge  logAgeErr   distKpc  distKpc_68U  distKpc_68L  distErrKpc  \
# 0  0.926959   0.099283  0.999538     1.015051     0.984918    0.015067
# 1  0.554307   0.099633  1.752755     1.780253     1.726831    0.026711
# 2 -0.300596   0.041403  1.645128     1.657617     1.631548    0.013035
# 3  0.844546   0.096625  1.173659     1.190136     1.154782    0.017677
# 4  0.982904   0.097514  0.849253     0.860659     0.836566    0.012047
#
#    logDistKpc  logDistKpcErr
# 0   -0.000201       0.006544
# 1    0.243721       0.006616
# 2    0.216200       0.003442
# 3    0.069542       0.006548
# 4   -0.070963       0.006166
#
# [5 rows x 38 columns]

# %%
data_train, data_test = train_test_split(data, test_size = 0.20, random_state = 42)

# %%
data_train.head()
# Out:
#                APOGEE_ID            source_id      LOGG         TEFF  \
# 1084  2M19210586+4512568  2127074448747065088  2.528896  4618.482422
# 1425  2M19275194+4432140  2126551802766566784  2.591600  4693.142578
# 2872  2M19555453+4637075  2085505040840529408  2.505609  4856.208984
# 2595  2M19492605+4733049  2086380458255298688  3.127957  4975.877930
# 1410  2M19273465+3850493  2052764470784039168  2.478781  4778.781738
#
#          MG_FE    FE_H_1      C_FE      N_FE          G         BP  ...  \
# 1084  0.249912 -0.297972  0.168490  0.056509  13.001588  13.619867  ...
# 1425 -0.009744  0.024268 -0.020912  0.255499  11.797462  12.399446  ...
# 2872 -0.000741 -0.004339 -0.048061  0.231635  10.448584  11.064596  ...
# 2595  0.014379 -0.069816 -0.062461  0.249710  11.898893  12.418426  ...
# 1410 -0.015421  0.057593 -0.039932  0.230346  11.588008  12.180071  ...
#
#       age_68L   ageErr    logAge  logAgeErr   distKpc  distKpc_68U  \
# 1084   8.9660  3.17035  1.019665   0.116141  2.131597     2.165136
# 1425   3.7584  1.25425  0.749427   0.111025  1.328182     1.352511
# 2872   2.2688  0.13555  0.379795   0.024510  0.849586     0.856019
# 2595   2.9854  0.85270  0.572616   0.098122  0.985641     1.000090
# 1410   3.5892  0.54525  0.605617   0.057610  1.479203     1.492124
#
#       distKpc_68L  distErrKpc  logDistKpc  logDistKpcErr
# 1084     2.094643    0.035247    0.328705       0.007188
# 1425     1.310690    0.020910    0.123258       0.006820
# 2872     0.843995    0.006012   -0.070793       0.003072
# 2595     0.971628    0.014231   -0.006281       0.006270
# 1410     1.467236    0.012444    0.170028       0.003653
#
# [5 rows x 38 columns]

# %%
len(data_train)
# Out:
# 2407

# %%
len(data_test)
# Out:
# 602

# %%
data_train.to_csv('../train_data/TrainingOriginal.csv')
data_test.to_csv('../test_data/TestOriginal.csv')
