# %% [markdown]
# # Small code to split the original data into training and testing sets

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

np.random.seed(1234)

# %%
data = pd.read_csv('AllOriginal.csv')
print("Length of data before dropping NaN: ", len(data))
data = data.dropna()
print("Length of data after dropping NaN: ", len(data))
# Out:
# Length of data before dropping NaN:  3016
# Length of data after dropping NaN:  3015

# %%
data.head()
# Out:
#             APOGEE_ID            source_id      LOGG         TEFF   ALPHA_M  \
# 0  2M18401969+4348380  2117126509915136384  2.871106  4723.436035  0.010860
# 1  2M18405556+4353012  2117149874537225344  3.000676  4952.732910  0.017616
# 2  2M18410298+4315506  2116830779945635200  2.901085  5117.872559 -0.042822
# 3  2M18413176+4358551  2116969387130311040  3.180513  4796.577148 -0.010190
# 4  2M18420846+4315092  2116909291947572736  3.039876  4725.524902  0.059750
#
#         M_H      C_FE      N_FE          G         BP  ...  age_68L   ageErr  \
# 0  0.066994 -0.016018  0.197207  11.753538  12.318904  ...   6.8391  1.98220
# 1 -0.168992 -0.012749  0.202450  12.680544  13.187252  ...   2.8510  0.82995
# 2 -0.002116 -0.104168  0.372032  11.452943  11.927316  ...   0.4732  0.04970
# 3  0.192128  0.041310  0.296720  12.788189  13.337189  ...   5.6442  1.58165
# 4  0.154598  0.133760  0.215050  11.997146  12.540438  ...   7.7625  2.20010
#
#      logAge  logAgeErr   distKpc  distKpc_68U  distKpc_68L  distErrKpc  \
# 0  0.926959   0.099283  0.999538     1.015051     0.984918    0.015067
# 1  0.554307   0.099633  1.752755     1.780253     1.726831    0.026711
# 2 -0.300596   0.041403  1.645128     1.657617     1.631548    0.013035
# 3  0.844546   0.096625  1.173659     1.190136     1.154782    0.017677
# 4  0.982904   0.097514  0.849253     0.860659     0.836566    0.012047
#
#    logDistKpc  logDistKpcErr
# 0   -0.000201       0.006544
# 1    0.243721       0.006616
# 2    0.216200       0.003442
# 3    0.069542       0.006548
# 4   -0.070963       0.006166
#
# [5 rows x 38 columns]

# %%
data_train, data_test = train_test_split(data, test_size = 0.20, random_state = 42)

# %%
data_train.head()
# Out:
#                APOGEE_ID            source_id      LOGG         TEFF  \
# 96    2M18505286+4432362  2105362083394042496  2.612084  4532.023438
# 1370  2M19263832+4240515  2125791318679254784  2.668956  4594.943848
# 2583  2M19491405+4134233  2076894284238667904  2.571587  4655.399902
# 1405  2M19272602+4221542  2125771390030125056  2.731084  4722.627930
# 1584  2M19305546+3815037  2051928738868317440  2.938272  5037.334473
#
#        ALPHA_M       M_H      C_FE      N_FE          G         BP  ...  \
# 96    0.049382  0.182148  0.098425  0.225120  11.437590  12.047989  ...
# 1370 -0.004179  0.161458  0.051968  0.201030  12.541131  13.154683  ...
# 2583 -0.013900 -0.010092 -0.011852  0.206955   9.852841  10.439758  ...
# 1405  0.000270  0.067287  0.014740  0.238237  12.800866  13.385051  ...
# 1584 -0.031977  0.165698 -0.135970  0.452220  11.157132  11.683986  ...
#
#       age_68L  ageErr    logAge  logAgeErr   distKpc  distKpc_68U  \
# 96     9.8855  1.6359  1.075021   0.062084  0.949597     0.959346
# 1370   7.7786  1.4048  0.944004   0.066960  1.661610     1.680687
# 2583   2.9080  0.6538  0.506519   0.080632  0.631819     0.640135
# 1405   2.8510  0.8443  0.542153   0.101010  2.151779     2.185176
# 1584   0.6095  0.0123 -0.207889   0.008592  1.164437     1.170807
#
#       distKpc_68L  distErrKpc  logDistKpc  logDistKpcErr
# 96       0.940806    0.009270   -0.022461       0.004238
# 1370     1.646228    0.017229    0.220529       0.004498
# 2583     0.623017    0.008559   -0.199407       0.005886
# 1405     2.119093    0.033042    0.332798       0.006668
# 1584     1.157657    0.006575    0.066116       0.002453
#
# [5 rows x 38 columns]

# %%
len(data_train)
# Out:
# 2412

# %%
len(data_test)
# Out:
# 603

# %%
data_train.to_csv('../train_data/TrainingOriginal.csv')
data_test.to_csv('../test_data/TestOriginal.csv')
